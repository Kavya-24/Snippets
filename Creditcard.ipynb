# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import calendar
import copy
from seaborn import set

# %%
try:
    data1 = pd.read_csv(r"C:\Users\Dell\Documents\Project 1\Credit.csv")
    print('File successfully loaded into the DataFrame..')
except:
    print("File not found...")
# Out:
# File successfully loaded into the DataFrame..

# %%
#Show all the columns present in the DataSet
data1.columns
# Out:
# Index(['card', 'reports', 'age', 'income', 'share', 'expenditure', 'owner',
#        'selfemp', 'dependents', 'months', 'majorcards', 'active'],
#       dtype='object')

# %%
#Displaying the first 10 data of the dataset
data1.head(10)
# Out:
#   card  reports       age  income     share  expenditure owner selfemp  \
# 0  yes        0  37.66667  4.5200  0.033270   124.983300   yes      no
# 1  yes        0  33.25000  2.4200  0.005217     9.854167    no      no
# 2  yes        0  33.66667  4.5000  0.004156    15.000000   yes      no
# 3  yes        0  30.50000  2.5400  0.065214   137.869200    no      no
# 4  yes        0  32.16667  9.7867  0.067051   546.503300   yes      no
# 5  yes        0  23.25000  2.5000  0.044438    91.996670    no      no
# 6  yes        0  27.91667  3.9600  0.012576    40.833330    no      no
# 7  yes        0  29.16667  2.3700  0.076434   150.790000   yes      no
# 8  yes        0  37.00000  3.8000  0.245628   777.821700   yes      no
# 9  yes        0  28.41667  3.2000  0.019780    52.580000    no      no
#
#    dependents  months  majorcards  active
# 0           3      54           1      12
# 1           3      34           1      13
# 2           4      58           1       5
# ...

# %%
#Displaying the last 10 data of the dataset
data1.tail(10)
# Out:
#      card  reports       age  income     share  expenditure owner selfemp  \
# 1309  yes        1  40.16667  2.0000  0.254827   424.629200   yes      no
# 1310  yes        0  30.58333  2.5120  0.002627     4.583333    no     yes
# 1311   no        0  39.33333  2.3004  0.000522     0.000000    no     yes
# 1312   no        0  22.58333  3.8600  0.000311     0.000000    no      no
# 1313   no        1  30.33333  2.1800  0.000550     0.000000    no     yes
# 1314  yes        0  33.58333  4.5660  0.002146     7.333333   yes      no
# 1315   no        5  23.91667  3.1920  0.000376     0.000000    no      no
# 1316  yes        0  40.58333  4.6000  0.026513   101.298300   yes      no
# 1317  yes        0  32.83333  3.7000  0.008999    26.996670    no     yes
# 1318  yes        0  48.25000  3.7000  0.111619   344.157500   yes      no
#
#       dependents  months  majorcards  active
# 1309           1     121           1      10
# 1310           3      36           0       4
# ...

# %%
data1.shape
# Out:
# (1319, 12)

# %%
data1.dtypes
# Out:
# card            object
# reports          int64
# age            float64
# income         float64
# share          float64
# expenditure    float64
# owner           object
# selfemp         object
# dependents       int64
# months           int64
# majorcards       int64
# active           int64
# dtype: object

# %%
# General Information about the Data Set
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1319 entries, 0 to 1318
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   card         1319 non-null   object
#  1   reports      1319 non-null   int64
#  2   age          1319 non-null   float64
#  3   income       1319 non-null   float64
#  4   share        1319 non-null   float64
#  5   expenditure  1319 non-null   float64
#  6   owner        1319 non-null   object
#  7   selfemp      1319 non-null   object
#  8   dependents   1319 non-null   int64
#  9   months       1319 non-null   int64
#  10  majorcards   1319 non-null   int64
#  11  active       1319 non-null   int64
# dtypes: float64(4), int64(5), object(3)
# memory usage: 123.8+ KB

# %%
#Describing the statistical information only for numerical columns
data1.describe()
# Out:
#            reports          age       income        share  expenditure  \
# count  1319.000000  1319.000000  1319.000000  1319.000000  1319.000000
# mean      0.456406    33.213103     3.365376     0.068732   185.057071
# std       1.345267    10.142783     1.693902     0.094656   272.218917
# min       0.000000     0.166667     0.210000     0.000109     0.000000
# 25%       0.000000    25.416670     2.243750     0.002316     4.583333
# 50%       0.000000    31.250000     2.900000     0.038827   101.298300
# 75%       0.000000    39.416670     4.000000     0.093617   249.035800
# max      14.000000    83.500000    13.500000     0.906320  3099.505000
#
#         dependents       months   majorcards       active
# count  1319.000000  1319.000000  1319.000000  1319.000000
# mean      0.993935    55.267627     0.817286     6.996967
# std       1.247745    66.271746     0.386579     6.305812
# min       0.000000     0.000000     0.000000     0.000000
# ...

# %%
# Sum of null value in each column
data1.isnull().sum()
# Out:
# card           0
# reports        0
# age            0
# income         0
# share          0
# expenditure    0
# owner          0
# selfemp        0
# dependents     0
# months         0
# majorcards     0
# active         0
# dtype: int64

# %%
plt.figure(figsize=(10,3))
plt.rcParams['axes.labelsize']=15
plt.rcParams['ytick.labelsize']=13
plt.rcParams['xtick.labelsize']=13
plt.title('HEATMAP FOR FOLLOWING DATA')
sns.heatmap(data1.isnull(),yticklabels=False,cbar=True,cmap='viridis')

# %%
print('The no. of duplicates in the data are',data1.duplicated().sum())
# Out:
# The no. of duplicates in the data are 0

# %%
data1.corr()
# Out:
#               reports       age    income     share  expenditure  dependents  \
# reports      1.000000  0.044089  0.011023 -0.159011    -0.136538    0.019731
# age          0.044089  1.000000  0.324653 -0.115697     0.014948    0.212146
# income       0.011023  0.324653  1.000000 -0.054429     0.281104    0.317601
# share       -0.159011 -0.115697 -0.054429  1.000000     0.838779   -0.082618
# expenditure -0.136538  0.014948  0.281104  0.838779     1.000000    0.052664
# dependents   0.019731  0.212146  0.317601 -0.082618     0.052664    1.000000
# months       0.048968  0.436426  0.130346 -0.055348    -0.029007    0.046512
# majorcards  -0.007304  0.009777  0.107138  0.051470     0.077514    0.010285
# active       0.207755  0.181070  0.180540 -0.023474     0.054724    0.107133
#
#                months  majorcards    active
# reports      0.048968   -0.007304  0.207755
# age          0.436426    0.009777  0.181070
# income       0.130346    0.107138  0.180540
# ...

# %%
plt.title('NUMBER OF CREDIT CARDS ISSUED')
plt.rcParams['axes.labelsize']=12
sns.countplot(x=data1.card)

# %%
plt.title('NUMBER OF APPLICANTS SELF EMPLOYED ')
plt.rcParams['axes.labelsize']=12
sns.countplot(x=data1.selfemp)

# %%
plt.title('NUMBER OF APPLICANTS OWING FLATS')
plt.rcParams['axes.labelsize']=12
sns.countplot(x=data1.owner)

# %%
plt.title('NUMBER OF MAJOR CARDS ')
plt.rcParams['axes.labelsize']=12
sns.countplot(x=data1.majorcards)

# %%
plt.title('NUMBER OF DEPENDENTS')
plt.rcParams['axes.labelsize']=12
sns.countplot(x=data1.dependents)

# %%
Self_yes = data1[data1['selfemp']=='yes']
Self_yes.head()
# Out:
#    card  reports       age  income     share  expenditure owner selfemp  \
# 18  yes        0  39.50000  9.9999  0.065795     548.0350   yes     yes
# 26   no        0  21.66667  3.8400  0.000313       0.0000    no     yes
# 45   no        0  28.16667  1.8000  0.000667       0.0000    no     yes
# 65   no        0  26.16667  2.5000  0.000480       0.0000    no     yes
# 66  yes        0  40.75000  6.0000  0.061240     306.0317    no     yes
#
#     dependents  months  majorcards  active
# 18           0      28           1       0
# 26           1      12           0       1
# 45           2      26           1       2
# 65           0      18           0       0
# 66           2     182           1      16

# %%
plt.title('NUMBER OF DEPENDENTS AS PER SELF EMPLOYED APPLICANTS')
plt.rcParams['axes.labelsize']=12
sns.countplot(x=Self_yes.dependents)

# %%
Self_no = data1[data1['selfemp']=='no']
Self_no.head()
# Out:
#   card  reports       age  income     share  expenditure owner selfemp  \
# 0  yes        0  37.66667  4.5200  0.033270   124.983300   yes      no
# 1  yes        0  33.25000  2.4200  0.005217     9.854167    no      no
# 2  yes        0  33.66667  4.5000  0.004156    15.000000   yes      no
# 3  yes        0  30.50000  2.5400  0.065214   137.869200    no      no
# 4  yes        0  32.16667  9.7867  0.067051   546.503300   yes      no
#
#    dependents  months  majorcards  active
# 0           3      54           1      12
# 1           3      34           1      13
# 2           4      58           1       5
# 3           0      25           1       7
# 4           2      64           1       5

# %%
plt.title('NUMBER OF DEPENDENTS AS PER UNEMPLOYED APPLICANTS')
plt.rcParams['axes.labelsize']=12
sns.countplot(x=Self_no.dependents)

# %%
corr = data1.corr()
plt.figure(figsize=(15,8))
sns.heatmap(corr, annot=True, annot_kws={"size": 15})

# %%
data1['age_group'] = pd.cut(data1.age, [21,40,60,81], labels=["young","middle","senior"])
data1.head()
# Out:
#   card  reports       age  income     share  expenditure owner selfemp  \
# 0  yes        0  37.66667  4.5200  0.033270   124.983300   yes      no
# 1  yes        0  33.25000  2.4200  0.005217     9.854167    no      no
# 2  yes        0  33.66667  4.5000  0.004156    15.000000   yes      no
# 3  yes        0  30.50000  2.5400  0.065214   137.869200    no      no
# 4  yes        0  32.16667  9.7867  0.067051   546.503300   yes      no
#
#    dependents  months  majorcards  active age_group
# 0           3      54           1      12     young
# 1           3      34           1      13     young
# 2           4      58           1       5     young
# 3           0      25           1       7     young
# 4           2      64           1       5     young

# %%
data1[data1['age_group'] == 'senior'].head(10)
# Out:
#     card  reports       age  income     share  expenditure owner selfemp  \
# 159  yes        0  71.83334  7.7010  0.062511    400.91170   yes      no
# 207   no        6  62.91667  2.5500  0.000471      0.00000    no      no
# 216  yes        0  61.08333  4.3200  0.036972    132.85080   yes      no
# 254  yes        0  65.91666  2.9500  0.048561    118.71330   yes      no
# 285  yes        0  63.50000  6.4532  0.000186      0.00000   yes      no
# 363  yes        0  61.00000  1.5000  0.268517    335.56250   yes      no
# 430  yes        0  63.16667  5.5000  0.020482     93.62500   yes      no
# 473  yes        0  62.00000  1.6380  0.047002     64.07417   yes      no
# 691  yes        1  60.08333  6.1000  0.094348    479.43670   yes      no
# 695   no        0  66.50000  3.2500  0.000369      0.00000   yes      no
#
#      dependents  months  majorcards  active age_group
# 159           1      24           1       9    senior
# 207           2      20           0      13    senior
# ...

# %%
plt.figure(figsize=(15,8))
sns.set_style('whitegrid')
sns.violinplot('age_group', 'expenditure', data = data1, hue = 'owner')

# %%
data1["age"]=pd.to_numeric(data1["age"])

# %%
data1["age"].head(10)
# Out:
# 0    37.66667
# 1    33.25000
# 2    33.66667
# 3    30.50000
# 4    32.16667
# 5    23.25000
# 6    27.91667
# 7    29.16667
# 8    37.00000
# 9    28.41667
# Name: age, dtype: float64

# %%
def plotDistPlot(col):
    sns.distplot(col)
    plt.show()
plotDistPlot(data1["age"])

# %%
plotDistPlot(data1["income"])

# %%
plotDistPlot(data1["share"])

# %%
plotDistPlot(data1["expenditure"])

# %%
plotDistPlot(data1["dependents"])

# %%
plotDistPlot(data1["months"])

# %%
plotDistPlot(data1["active"])

# %%
sns.set()
cols=['age','income','share']
sns.pairplot(data1[cols],size=5.0)
plt.show();
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\axisgrid.py:2071: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
cols=['expenditure','reports','dependents']
sns.pairplot(data1[cols],size=5.0)
plt.show();

# %%
cols=['months','majorcards','active']
sns.pairplot(data1[cols],size=5.0)
plt.show();

# %%
def impute_accepted(cols):
    Reports=cols[0]
    Age=cols[1]
    Share=cols[2]
    Income=cols[3]
    if (Reports>2 or Age<18 or Age>60 or Share<=0.00099 or (Income*100000)<250000):
        return 0
    else:
        return 1

# %%
data1['accepted']=data1[['reports','age','share','income']].apply(impute_accepted,axis=1)
data1.head(10)
# Out:
#   card  reports       age  income     share  expenditure owner selfemp  \
# 0  yes        0  37.66667  4.5200  0.033270   124.983300   yes      no
# 1  yes        0  33.25000  2.4200  0.005217     9.854167    no      no
# 2  yes        0  33.66667  4.5000  0.004156    15.000000   yes      no
# 3  yes        0  30.50000  2.5400  0.065214   137.869200    no      no
# 4  yes        0  32.16667  9.7867  0.067051   546.503300   yes      no
# 5  yes        0  23.25000  2.5000  0.044438    91.996670    no      no
# 6  yes        0  27.91667  3.9600  0.012576    40.833330    no      no
# 7  yes        0  29.16667  2.3700  0.076434   150.790000   yes      no
# 8  yes        0  37.00000  3.8000  0.245628   777.821700   yes      no
# 9  yes        0  28.41667  3.2000  0.019780    52.580000    no      no
#
#    dependents  months  majorcards  active age_group  accepted
# 0           3      54           1      12     young         1
# 1           3      34           1      13     young         0
# ...

# %%
plt.title('NUMBER OF CREDIT CARDS ACCEPTED')
plt.rcParams['axes.labelsize']=12
sns.countplot(x=data1.accepted)

# %%
a,c=[],[]
for g,d in data1.groupby('age_group'):
        a.append(g)
        c.append(d.accepted.sum())
plt.figure(figsize=(10,4))
plt.grid(True)
plt.title('CREDIT CARD ACCEPTED AS PER AGE RESTRICTION')
gc=pd.DataFrame(dict(accepted=c,age_group=a),columns=['accepted','age_group']).sort_values(ascending=False,by='accepted')
sns.barplot(data=gc,y='age_group',x='accepted',ci=None)

# %%
a,c=[],[]
for g,d in data1.groupby('owner'):
        a.append(g)
        c.append(d.accepted.sum())
plt.figure(figsize=(10,4))
plt.grid(True)
plt.title('CREDIT CARD ACCEPTED AS PER HOUSE OWNERSHIP')
gc=pd.DataFrame(dict(accepted=c,owner=a),columns=['accepted','owner']).sort_values(ascending=False,by='accepted')
sns.barplot(data=gc,y='owner',x='accepted',ci=None)

# %%
from sklearn.model_selection import train_test_split
X = data1[['share', 'income','age','reports']]
y = data1['accepted']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

from sklearn.linear_model import LogisticRegression

logmodel = LogisticRegression()

logmodel.fit(X_train,y_train)

predictions = logmodel.predict(X_test)

from sklearn.metrics import accuracy_score
print("Logistic regression classifier has accuracy of :",accuracy_score(y_test, predictions)*100)
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, predictions)
# Out:
# Logistic regression classifier has accuracy of : 84.63302752293578
# array([[192,  31],
#        [ 36, 177]], dtype=int64)

# %%
X = data1[['share', 'reports','age']]
y = data1['accepted']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=101)

from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier(n_estimators=600)

rfc.fit(X_train,y_train)

predictions = rfc.predict(X_test)

from sklearn.metrics import accuracy_score
print("Random Forest Classifier has accuracy of :",accuracy_score(y_test, predictions)*100)
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, predictions)
# Out:
# Random Forest Classifier has accuracy of : 77.27272727272727
# array([[135,  49],
#        [ 41, 171]], dtype=int64)

# %%
X = data1[['share','reports','age']]
y = data1['accepted']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=101)

from sklearn.tree import DecisionTreeClassifier

dtree = DecisionTreeClassifier()

dtree.fit(X_train,y_train)

predictions = dtree.predict(X_test)

from sklearn.metrics import accuracy_score
accuracy_score(y_test, predictions)*100
# Out:
# 72.97979797979798

# %%
X = data1[['share', 'income','age','reports']]
y = data1['accepted']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
param_grid = {'C': [0.1,1, 10, 100], 'gamma': [1,0.1,0.01,0.001]} 
grid = GridSearchCV(SVC(),param_grid,refit=True,verbose=2)
grid.fit(X_train,y_train)
grid_predictions = grid.predict(X_test)

from sklearn.metrics import accuracy_score
print("Best :", accuracy_score(y_test, grid_predictions)*100)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV] C=0.1, gamma=1 ..................................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [CV] ................................... C=0.1, gamma=1, total=   0.1s
# [CV] C=0.1, gamma=1 ..................................................
# [CV] ................................... C=0.1, gamma=1, total=   0.1s
# [CV] C=0.1, gamma=1 ..................................................
# [CV] ................................... C=0.1, gamma=1, total=   0.1s
# [CV] C=0.1, gamma=1 ..................................................
# [CV] ................................... C=0.1, gamma=1, total=   0.1s
# [CV] C=0.1, gamma=1 ..................................................
# [CV] ................................... C=0.1, gamma=1, total=   0.1s
# ...

# %%
plt.figure(figsize=(12,7))
n1=data1[data1['age_group'].isin(data1['age_group'].value_counts()[0:3].index)][['age_group','income']]
plt.ylim(-1,15)
plt.title('AGE GROUP')
sns.boxplot(x='age_group',y='income',data=n1,palette='winter')

# %%
plt.figure(figsize=(12,7))
n1=data1[data1['age_group'].isin(data1['age_group'].value_counts()[0:3].index)][['age_group','dependents']]
plt.ylim(-1,10)
plt.title('AGE GROUP')
sns.boxplot(x='age_group',y='dependents',data=n1,palette='winter')

# %%
plt.figure(figsize=(12,7))
n1=data1[data1['age_group'].isin(data1['age_group'].value_counts()[0:3].index)][['age_group','expenditure']]
plt.ylim(-1,2000)
plt.title('AGE GROUP')
sns.boxplot(x='age_group',y='expenditure',data=n1,palette='winter')

# %%
plt.figure(figsize=(12,7))
n1=data1[data1['age_group'].isin(data1['age_group'].value_counts()[0:3].index)][['age_group','months']]
plt.ylim(-1,600)
plt.title('AGE GROUP')
sns.boxplot(x='age_group',y='months',data=n1,palette='winter')

# %%
plt.figure(figsize=(12,7))
n1=data1[data1['age_group'].isin(data1['age_group'].value_counts()[0:3].index)][['age_group','active']]
plt.ylim(-1,50)
plt.title('AGE GROUP')
sns.boxplot(x='age_group',y='active',data=n1,palette='winter')

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

for col in data1:
    if data1[col].dtypes=='object':
        data1[col]=le.fit_transform(data1[col])

# %%
data1.tail(10)
# Out:
#       card  reports       age  income     share  expenditure  owner  selfemp  \
# 1309     1        1  40.16667  2.0000  0.254827   424.629200      1        0
# 1310     1        0  30.58333  2.5120  0.002627     4.583333      0        1
# 1311     0        0  39.33333  2.3004  0.000522     0.000000      0        1
# 1312     0        0  22.58333  3.8600  0.000311     0.000000      0        0
# 1313     0        1  30.33333  2.1800  0.000550     0.000000      0        1
# 1314     1        0  33.58333  4.5660  0.002146     7.333333      1        0
# 1315     0        5  23.91667  3.1920  0.000376     0.000000      0        0
# 1316     1        0  40.58333  4.6000  0.026513   101.298300      1        0
# 1317     1        0  32.83333  3.7000  0.008999    26.996670      0        1
# 1318     1        0  48.25000  3.7000  0.111619   344.157500      1        0
#
#       dependents  months  majorcards  active age_group  accepted
# ...

# %%
importances=rfc.feature_importances_
std=np.std([tree.feature_importances_ for tree in rfc.estimators_],axis=0)
indices=np.argsort(importances)[::-1]
print("Feature ranking :")
for f in range(X.shape[1]):
    print("%d. feature %d (%f)" % (f+1, indices[f], importances[indices[f]]))
# Out:
# Feature ranking :
# 1. feature 0 (0.583219)
# 2. feature 2 (0.362989)
# 3. feature 1 (0.053792)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-55-f8221cd64af0> in <module>
#       4 print("Feature ranking :")
#       5 for f in range(X.shape[1]):
# ----> 6     print("%d. feature %d (%f)" % (f+1, indices[f], importances[indices[f]]))
#
# IndexError: index 3 is out of bounds for axis 0 with size 3

# %%
plt.figure()
plt.title("Feature importances")
plt.bar(range(X.shape[1]),importances[indices],color="r",yerr=std[indices],align="center")
plt.xticks(range(X.shape[1]),indices)
plt.xlim([-1,X.shape[1]])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-a71eec59d0cd> in <module>
#       1 plt.figure()
#       2 plt.title("Feature importances")
# ----> 3 plt.bar(range(X.shape[1]),importances[indices],color="r",yerr=std[indices],align="center")
#       4 plt.xticks(range(X.shape[1]),indices)
#       5 plt.xlim([-1,X.shape[1]])
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2405         x, height, width=0.8, bottom=None, *, align='center',
#    2406         data=None, **kwargs):
# -> 2407     return gca().bar(
#    2408         x, height, width=width, bottom=bottom, align=align,
#    2409         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
features=data1.columns
plt.title("Feature importances")
plt.barh(range(len(indices)),importances[indices],color="b",align="center")
plt.yticks(range(len(indices)),[features[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()
